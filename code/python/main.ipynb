# %%
import os
import sys

import numpy as np
import pandas as pd

# %%
intermediate_path = '../../intermediate'
# Task index from SLURM array to run specific variable and model combinations
task_id = 0
# Task list csv
task_list = 'test_run_manager_explicit_list.csv'
# Extract task details
task_details = pd.read_csv(os.path.join(intermediate_path, task_list)).iloc[task_id]

# %%
task_details
# Out:
# ESM                                                                model-name
# Variable                                                                 hurs
# Scenario                                                        scenario-name
# Ensemble                                                        ensemble-name
# Reference_Dataset                                                    obs-hist
# target_period                                                       1979-2014
# application_period                                                  2065-2100
# ESM_Input_Location          /Users/prim232/gitrepos/basd-pipeline/input/te...
# Reference_Input_Location    /Users/prim232/gitrepos/basd-pipeline/input/te...
# Output_Location             /Users/prim232/gitrepos/basd-pipeline/output/t...
# daily                                                                    True
# monthly                                                                  True
# Name: 0, dtype: object

# %%
if ~task_details.monthly:
    print('yes')

# %%
task_details.ESM_Input_Location
# Out:
# '/Users/prim232/gitrepos/basd-pipeline/input/test_data/sim'

# %%
pd.isna(task_details.ESM_Input_Location)
# Out:
# False

# %%
start, end = str.split(task_details.application_period, '-')
print(f'{start}_{end}')
# Out:
# 2065_2100

# %%
input_path = '../../input'
param_data = pd.read_csv(os.path.join(input_path, 'variable_parameters.csv'))
param_data
# Out:
#     variable distribution  lower_bound  lower_threshold  upper_bound  \
# 0       hurs         beta          0.0         0.010000        100.0
# 1         pr        gamma          0.0         0.000001          NaN
# 2        tas       normal          NaN              NaN          NaN
# 3     tasmax          NaN          NaN              NaN          NaN
# 4     tasmin          NaN          NaN              NaN          NaN
# 5       rlds       normal          NaN              NaN          NaN
# 6       rsds         beta          0.0         0.000100          1.0
# 7    sfcWind      weibull          0.0         0.010000          NaN
# 8         ps          NaN          NaN              NaN          NaN
# 9   tasrange         rice          0.0         0.010000          NaN
# 10   tasskew         beta          0.0         0.000100          1.0
#
#     upper_threshold trend_preservation  n_iterations detrend  \
# 0           99.9900            bounded            10     NaN
# 1               NaN              mixed            10     NaN
# 2               NaN           additive            10    True
# 3               NaN                NaN            10     NaN
# 4               NaN                NaN            10     NaN
# 5               NaN           additive            10    True
# 6            0.9999            bounded            10     NaN
# 7               NaN              mixed            10     NaN
# 8               NaN                NaN            10     NaN
# 9               NaN              mixed            10     NaN
# 10           0.9999            bounded            10     NaN
#
#     if_all_invalid_use  ...  halfwin_ubc  n_quantiles  randomization_seed  \
# 0                    0  ...          NaN          NaN                 NaN
# 1                    0  ...          NaN          NaN                 NaN
# 2                    0  ...          NaN          NaN                 NaN
# 3                    0  ...          NaN          NaN                 NaN
# 4                    0  ...          NaN          NaN                 NaN
# 5                    0  ...          NaN          NaN                 NaN
# 6                    0  ...         15.0          NaN                 NaN
# 7                    0  ...          NaN          NaN                 NaN
# 8                    0  ...          NaN          NaN                 NaN
# 9                    0  ...          NaN          NaN                 NaN
# 10                   0  ...          NaN          NaN                 NaN
#
#     max_change_factor  max_adjustment_factor  parametric  \
# 0                 NaN                    NaN         NaN
# 1                 NaN                    NaN         NaN
# 2                 NaN                    NaN         NaN
# 3                 NaN                    NaN         NaN
# 4                 NaN                    NaN         NaN
# 5                 NaN                    NaN         NaN
# 6                 NaN                    NaN         NaN
# 7                 NaN                    NaN         NaN
# 8                 NaN                    NaN         NaN
# 9                 NaN                    NaN         NaN
# 10                NaN                    NaN         NaN
#
#     unconditional_ccs_transfer  trendless_bound_frequency  p_value_eps  \
# 0                          NaN                        NaN          NaN
# 1                          NaN                        NaN          NaN
# 2                          NaN                        NaN          NaN
# 3                          NaN                        NaN          NaN
# 4                          NaN                        NaN          NaN
# 5                          NaN                        NaN          NaN
# 6                          NaN                        NaN          NaN
# 7                          NaN                        NaN          NaN
# 8                          NaN                        NaN          NaN
# 9                          NaN                        NaN          NaN
# 10                         NaN                        NaN          NaN
#
#     adjust_p_values
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
#
# [11 rows x 22 columns]

# %%
pd.isna(param_data.iloc[0].detrend)
# Out:
# True

# %%
import basd

# %%
param_dict = param_data[param_data.variable == 'pr'].dropna(axis=1).to_dict(orient='records')[0]
del param_dict['variable']
param_dict
# Out:
# {'distribution': 'gamma',
#  'lower_bound': 0.0,
#  'lower_threshold': 1.16e-06,
#  'trend_preservation': 'mixed',
#  'n_iterations': 10,
#  'if_all_invalid_use': 0}

# %%
if 'n_iterations' in param_dict:
    param_dict['n_iterations'] = int(param_dict['n_iterations'])
param_dict
# Out:
# {'distribution': 'gamma',
#  'lower_bound': 0.0,
#  'lower_threshold': 1.16e-06,
#  'trend_preservation': 'mixed',
#  'n_iterations': 10,
#  'if_all_invalid_use': 0}

# %%
basd.Parameters(**param_dict)

# %%
encoding_data = pd.read_csv(os.path.join(input_path, 'encoding.csv'))
encoding_data
# Out:
#    zlib  shuffle  complevel  fletcher32  contiguous  time_chunk lat_chunk  \
# 0  True     True          5       False       False           1       max
#
#   lon_chunk    dtype  missing_value    _FillValue
# 0       max  float32   1.000000e+20  1.000000e+20

# %%
encoding_data_dict = encoding_data.dropna(axis=1).to_dict(orient='records')[0]
encoding_data_dict
# Out:
# {'zlib': True,
#  'shuffle': True,
#  'complevel': 5,
#  'fletcher32': False,
#  'contiguous': False,
#  'time_chunk': 1,
#  'lat_chunk': 'max',
#  'lon_chunk': 'max',
#  'dtype': 'float32',
#  'missing_value': 1e+20,
#  '_FillValue': 1e+20}

# %%
reset_encoding_chunks = False
if np.any( [pd.isna(encoding_data['time_chunk']), pd.isna(encoding_data['lat_chunk']), pd.isna(encoding_data['lon_chunk'])] ):
    del encoding_data_dict['time_chunk'], encoding_data_dict['lat_chunk'], encoding_data_dict['lon_chunk']
else:
    if 'max' in [encoding_data_dict['time_chunk'], encoding_data_dict['lat_chunk'], encoding_data_dict['lon_chunk']]:
        reset_encoding_chunks = True
        encoding_data_dict['chunksizes'] = (encoding_data_dict['time_chunk'], encoding_data_dict['lat_chunk'], encoding_data_dict['lon_chunk'])
    del encoding_data_dict['time_chunk'], encoding_data_dict['lat_chunk'], encoding_data_dict['lon_chunk']

# %%
reset_encoding_chunks
# Out:
# True

# %%
encoding_data_dict
# Out:
# {'zlib': True,
#  'shuffle': True,
#  'complevel': 5,
#  'fletcher32': False,
#  'contiguous': False,
#  'dtype': 'float32',
#  'missing_value': 1e+20,
#  '_FillValue': 1e+20,
#  'chunksizes': (1, 'max', 'max')}

# %%
encoding_data_dict['chunksizes'][0] == 'max'
# Out:
# False

# %%
dask_params = pd.read_csv(os.path.join(input_path, 'dask_parameters.csv'))
dask_params
# Out:
#    time_chunk_size  lat_chunk_size  lon_chunk_size  dask_temp_directory
# 0               50               5               5                  NaN

# %%
import utils

# %%
_,_,_,dask_temp_dir = utils.get_chunk_sizes(input_path)

# %%
dask_temp_dir
# Out:
# nan

# %%
if pd.isna(dask_temp_dir):
    print('it is na')
# Out:
# it is na

# %%
run_manager_df = pd.read_csv(os.path.join(input_path, 'run_manager.csv'))
run_manager_df
# Out:
#          ESM                                 ESM_Input_Location  \
# 0  GFDL-ESM4  /rcfs/projects/gcims/data/climate/cmip6/GFDL-ESM4
# 1    CanESM5                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4        NaN                                                NaN
# 5        NaN                                                NaN
# 6        NaN                                                NaN
# 7        NaN                                                NaN
#
#                                     Output_Location Reference_Dataset  \
# 0  /rcfs/projects/gcims/data/climate/basd/GFDL-ESM4            W5E5v2
# 1    /rcfs/projects/gcims/data/climate/basd/CanESM5               NaN
# 2                                               NaN               NaN
# 3                                               NaN               NaN
# 4                                               NaN               NaN
# 5                                               NaN               NaN
# 6                                               NaN               NaN
# 7                                               NaN               NaN
#
#                    Reference_Input_Location Variable Scenario  Ensemble  \
# 0  /rcfs/projects/gcims/data/climate/W5E5v2       pr   ssp245  r1i1p1f1
# 1                                       NaN      tas   ssp370       NaN
# 2                                       NaN     hurs      NaN       NaN
# 3                                       NaN  sfcWind      NaN       NaN
# 4                                       NaN     rsds      NaN       NaN
# 5                                       NaN     rlds      NaN       NaN
# 6                                       NaN   tasmin      NaN       NaN
# 7                                       NaN   tasmax      NaN       NaN
#
#   target_period application_period daily monthly
# 0     1970-2014          2015-2100  True    True
# 1           NaN          1950-2014   NaN     NaN
# 2           NaN                NaN   NaN     NaN
# 3           NaN                NaN   NaN     NaN
# 4           NaN                NaN   NaN     NaN
# 5           NaN                NaN   NaN     NaN
# 6           NaN                NaN   NaN     NaN
# 7           NaN                NaN   NaN     NaN

# %%
def remove_nas(x):
    return x[~pd.isnull(x)]

# %%
esms = remove_nas(run_manager_df['ESM'].values)
esm_input_paths = remove_nas(run_manager_df['ESM_Input_Location'].values)
output_paths = remove_nas(run_manager_df['Output_Location'].values)
ref_datasets = remove_nas(run_manager_df['Reference_Dataset'].values)
ref_datasets_paths = remove_nas(run_manager_df['Reference_Input_Location'].values)
variables = remove_nas(run_manager_df['Variable'].values)
scenarios = remove_nas(run_manager_df['Scenario'].values)
ensembles = remove_nas(run_manager_df['Ensemble'].values)
target_periods = remove_nas(run_manager_df['target_period'].values)
application_periods = remove_nas(run_manager_df['application_period'].values)
daily = remove_nas(run_manager_df['daily'].values)
monthly = remove_nas(run_manager_df['monthly'].values)

# %%
variables = np.intersect1d(variables, ['tasmin', 'tasmax'])

# %%
mesh_array = np.array(np.meshgrid(esms, 
                                  variables, 
                                  scenarios, 
                                  ensembles,
                                  ref_datasets, 
                                  target_periods, 
                                  application_periods)).T.reshape(-1,7)

# %%
mesh_df = pd.DataFrame(mesh_array, columns = ['ESM', 'Variable', 'Scenario', 'Ensemble', 'Reference_Dataset',
                                              'target_period', 'application_period'])
# Merge in esm input locations
mesh_df = mesh_df.merge(run_manager_df[['ESM', 'ESM_Input_Location']], on='ESM', how='inner')
# Merge in reference dataset input locations
mesh_df = mesh_df.merge(run_manager_df[['Reference_Dataset', 'Reference_Input_Location']], on='Reference_Dataset', how='inner')
# Merge in output paths
mesh_df = mesh_df.merge(run_manager_df[['ESM', 'Output_Location']], on='ESM', how='inner')
# Add daily and monthly bools
mesh_df['daily'] = daily[0]
mesh_df['monthly'] = monthly[0]
mesh_df
# Out:
#           ESM Variable Scenario  Ensemble Reference_Dataset target_period  \
# 0   GFDL-ESM4   tasmax   ssp245  r1i1p1f1            W5E5v2     1970-2014
# 1   GFDL-ESM4   tasmin   ssp245  r1i1p1f1            W5E5v2     1970-2014
# 2   GFDL-ESM4   tasmax   ssp370  r1i1p1f1            W5E5v2     1970-2014
# 3   GFDL-ESM4   tasmin   ssp370  r1i1p1f1            W5E5v2     1970-2014
# 4   GFDL-ESM4   tasmax   ssp245  r1i1p1f1            W5E5v2     1970-2014
# 5   GFDL-ESM4   tasmin   ssp245  r1i1p1f1            W5E5v2     1970-2014
# 6   GFDL-ESM4   tasmax   ssp370  r1i1p1f1            W5E5v2     1970-2014
# 7   GFDL-ESM4   tasmin   ssp370  r1i1p1f1            W5E5v2     1970-2014
# 8     CanESM5   tasmax   ssp245  r1i1p1f1            W5E5v2     1970-2014
# 9     CanESM5   tasmin   ssp245  r1i1p1f1            W5E5v2     1970-2014
# 10    CanESM5   tasmax   ssp370  r1i1p1f1            W5E5v2     1970-2014
# 11    CanESM5   tasmin   ssp370  r1i1p1f1            W5E5v2     1970-2014
# 12    CanESM5   tasmax   ssp245  r1i1p1f1            W5E5v2     1970-2014
# 13    CanESM5   tasmin   ssp245  r1i1p1f1            W5E5v2     1970-2014
# 14    CanESM5   tasmax   ssp370  r1i1p1f1            W5E5v2     1970-2014
# 15    CanESM5   tasmin   ssp370  r1i1p1f1            W5E5v2     1970-2014
#
#    application_period                                 ESM_Input_Location  \
# 0           2015-2100  /rcfs/projects/gcims/data/climate/cmip6/GFDL-ESM4
# 1           2015-2100  /rcfs/projects/gcims/data/climate/cmip6/GFDL-ESM4
# 2           2015-2100  /rcfs/projects/gcims/data/climate/cmip6/GFDL-ESM4
# 3           2015-2100  /rcfs/projects/gcims/data/climate/cmip6/GFDL-ESM4
# 4           1950-2014  /rcfs/projects/gcims/data/climate/cmip6/GFDL-ESM4
# 5           1950-2014  /rcfs/projects/gcims/data/climate/cmip6/GFDL-ESM4
# 6           1950-2014  /rcfs/projects/gcims/data/climate/cmip6/GFDL-ESM4
# 7           1950-2014  /rcfs/projects/gcims/data/climate/cmip6/GFDL-ESM4
# 8           2015-2100                                                NaN
# 9           2015-2100                                                NaN
# 10          2015-2100                                                NaN
# 11          2015-2100                                                NaN
# 12          1950-2014                                                NaN
# 13          1950-2014                                                NaN
# 14          1950-2014                                                NaN
# 15          1950-2014                                                NaN
#
#                     Reference_Input_Location  \
# 0   /rcfs/projects/gcims/data/climate/W5E5v2
# 1   /rcfs/projects/gcims/data/climate/W5E5v2
# 2   /rcfs/projects/gcims/data/climate/W5E5v2
# 3   /rcfs/projects/gcims/data/climate/W5E5v2
# 4   /rcfs/projects/gcims/data/climate/W5E5v2
# 5   /rcfs/projects/gcims/data/climate/W5E5v2
# 6   /rcfs/projects/gcims/data/climate/W5E5v2
# 7   /rcfs/projects/gcims/data/climate/W5E5v2
# 8   /rcfs/projects/gcims/data/climate/W5E5v2
# 9   /rcfs/projects/gcims/data/climate/W5E5v2
# 10  /rcfs/projects/gcims/data/climate/W5E5v2
# 11  /rcfs/projects/gcims/data/climate/W5E5v2
# 12  /rcfs/projects/gcims/data/climate/W5E5v2
# 13  /rcfs/projects/gcims/data/climate/W5E5v2
# 14  /rcfs/projects/gcims/data/climate/W5E5v2
# 15  /rcfs/projects/gcims/data/climate/W5E5v2
#
#                                      Output_Location  daily  monthly
# 0   /rcfs/projects/gcims/data/climate/basd/GFDL-ESM4   True     True
# 1   /rcfs/projects/gcims/data/climate/basd/GFDL-ESM4   True     True
# 2   /rcfs/projects/gcims/data/climate/basd/GFDL-ESM4   True     True
# 3   /rcfs/projects/gcims/data/climate/basd/GFDL-ESM4   True     True
# 4   /rcfs/projects/gcims/data/climate/basd/GFDL-ESM4   True     True
# 5   /rcfs/projects/gcims/data/climate/basd/GFDL-ESM4   True     True
# 6   /rcfs/projects/gcims/data/climate/basd/GFDL-ESM4   True     True
# 7   /rcfs/projects/gcims/data/climate/basd/GFDL-ESM4   True     True
# 8     /rcfs/projects/gcims/data/climate/basd/CanESM5   True     True
# 9     /rcfs/projects/gcims/data/climate/basd/CanESM5   True     True
# 10    /rcfs/projects/gcims/data/climate/basd/CanESM5   True     True
# 11    /rcfs/projects/gcims/data/climate/basd/CanESM5   True     True
# 12    /rcfs/projects/gcims/data/climate/basd/CanESM5   True     True
# 13    /rcfs/projects/gcims/data/climate/basd/CanESM5   True     True
# 14    /rcfs/projects/gcims/data/climate/basd/CanESM5   True     True
# 15    /rcfs/projects/gcims/data/climate/basd/CanESM5   True     True

# %%
for index, row in mesh_df.iterrows():
    print(f'{row.Variable}, {row.Scenario}, {row.ESM}, {row.Ensemble}, {row.application_period}')
# Out:
# tasmax, ssp245, GFDL-ESM4, r1i1p1f1, 2015-2100
# tasmin, ssp245, GFDL-ESM4, r1i1p1f1, 2015-2100
# tasmax, ssp370, GFDL-ESM4, r1i1p1f1, 2015-2100
# tasmin, ssp370, GFDL-ESM4, r1i1p1f1, 2015-2100
# tasmax, ssp245, GFDL-ESM4, r1i1p1f1, 1950-2014
# tasmin, ssp245, GFDL-ESM4, r1i1p1f1, 1950-2014
# tasmax, ssp370, GFDL-ESM4, r1i1p1f1, 1950-2014
# tasmin, ssp370, GFDL-ESM4, r1i1p1f1, 1950-2014
# tasmax, ssp245, CanESM5, r1i1p1f1, 2015-2100
# tasmin, ssp245, CanESM5, r1i1p1f1, 2015-2100
# tasmax, ssp370, CanESM5, r1i1p1f1, 2015-2100
# tasmin, ssp370, CanESM5, r1i1p1f1, 2015-2100
# tasmax, ssp245, CanESM5, r1i1p1f1, 1950-2014
# tasmin, ssp245, CanESM5, r1i1p1f1, 1950-2014
# tasmax, ssp370, CanESM5, r1i1p1f1, 1950-2014
# tasmin, ssp370, CanESM5, r1i1p1f1, 1950-2014
